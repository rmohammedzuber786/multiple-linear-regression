# %%
import pandas as pd

# %%
dataset=pd.read_csv('Salary_Data.csv')
dataset
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x=dataset.iloc[:,:-1].values;x
y=dataset.iloc[:,-1].values;y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %%
import matplotlib.pyplot as plt 
fig=plt.figure(figsize=(10,10))
ax1=fig.add_subplot(2,2,1)
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
ax2=fig.add_subplot(2,2,2)
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
ax3=fig.add_subplot(2,2,3)   
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
ax4=fig.add_subplot(2,2,4)   
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
ax1.plot(dataset['YearsExperience'][0:12],dataset['Salary'][0:12])
ax2.plot(dataset['YearsExperience'][24:48],dataset['Salary'][24:48])
ax3.plot(dataset['YearsExperience'][25:50],dataset['Salary'][25:50])
ax4.plot(dataset['YearsExperience'][24:50],dataset['Salary'][24:50])

plt.show()

# %%
import seaborn as sns
sns.lineplot(dataset['YearsExperience'],dataset['Salary'])
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='YearsExperience', ylabel='Salary'>

# %%
dataset[0:2]['YearsExperience']
#loc and iloc function...
# Out:
# 0    1.1
# 1    1.3
# Name: YearsExperience, dtype: float64

# %%
f500=pd.read_csv('f500.csv')
f500
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
f500.shape
# Out:
# (500, 17)

# %%
f500[0:50][['company','revenues','profits','ceo']]  
#loc ....writing the position...of the columns in string names...
#loc ....writing the position...of the columns in index basis... company=0,rank=1...etc
# Out:
#                                   company  revenues  profits  \
# 0                                 Walmart    485873  13643.0
# 1                              State Grid    315199   9571.3
# 2                           Sinopec Group    267518   1257.9
# 3                China National Petroleum    262573   1867.5
# 4                            Toyota Motor    254694  16899.3
# 5                              Volkswagen    240264   5937.3
# 6                       Royal Dutch Shell    240033   4575.0
# 7                      Berkshire Hathaway    223604  24074.0
# 8                                   Apple    215639  45687.0
# 9                             Exxon Mobil    205004   7840.0
# 10                               McKesson    198533   5070.0
# 11                                     BP    186606    115.0
# 12                     UnitedHealth Group    184840   7017.0
# 13                             CVS Health    177526   5317.0
# ...

# %%
f500.loc[[0,15,2,74],['company','revenues','profits','ceo']]        #loc [rowpositiom],[columns position]]
# Out:
#           company  revenues  profits                   ceo
# 0         Walmart    485873  13643.0   C. Douglas McMillon
# 15       Glencore    173883   1379.0       Ivan Glasenberg
# 2   Sinopec Group    267518   1257.9             Wang Yupu
# 74      Petrobras     81405  -4838.0  Pedro Pullen Parente

# %%
f500.iloc[[0,15,2,74],[0,7,2,4]]
# Out:
#           company                   ceo  revenues  profits
# 0         Walmart   C. Douglas McMillon    485873  13643.0
# 15       Glencore       Ivan Glasenberg    173883   1379.0
# 2   Sinopec Group             Wang Yupu    267518   1257.9
# 74      Petrobras  Pedro Pullen Parente     81405  -4838.0

# %%
x=dataset.iloc[:,0:-1].values;x 
y=dataset.iloc[:,-1].values;y

# %%
from sklearn.model_selection import train_test_split
y_train,y_test,x_train,x_test=train_test_split(y,x,train_size=1/2,random_state=0)
y_train
# Out:
# array([ 91738.,  46205., 121872.,  60150.,  39891.,  81363.,  93940.,
#         57189.,  54445., 105582.,  43525.,  39343.,  98273.,  67938.,
#         56957.])

# %%
from sklearn.model_selection import train_test_split
y_train,y_test,x_train,x_test=train_test_split(y,x,train_size=1/2,random_state=5)
y_trai
# Out:
# array([112635.,  56957.,  91738.,  93940., 109431.,  54445.,  39891.,
#         64445.,  57189.,  66029., 101302.,  60150.,  67938.,  61111.,
#         43525.])

# %%
from sklearn.linear_model import LinearRegression      #training set 
regression=LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
regression.intercept_
# Out:
# 23856.70639260797

# %%
regression.coef_
# Out:
# array([9664.10968063])

# %%
#x_test =0 to 30 th value
#y=b0+b1*x 
23856.70639260797+9664.10968063*4  #4 means first value of x like years of exp
# Out:
# 62513.14511512797

# %%
y_pred=regression.predict(x_test) #predicting the test set results
y_pred
# Out:
# array([ 62513.14511511, 125329.85803919, 103102.40577375, 110833.69351825,
#         80874.95350831,  61546.73414705,  38352.87091355,  63479.55608318,
#        115665.74835856,  92471.88512506, 123397.03610306,  34487.2270413 ,
#         75076.48769993,  51882.62446643,  36420.04897742])

# %%
y_test
# Out:
# array([ 55794., 121872., 113812., 105582.,  81363.,  63218.,  37731.,
#         57081., 116969.,  98273., 122391.,  39343.,  83088.,  56642.,
#         46205.])

# %%
#visualize the test set results
import matplotlib.pyplot as plt
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train,regression.predict(x_train),color='blue')
plt.show()
